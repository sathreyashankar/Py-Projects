# %% [markdown]
# ## Importing Libraries

# %%
import cv2
# import matplotlib.image as mping
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading image files

# %%
img1 = cv2.imread('Car.jpg')
img2 = cv2.imread('Car1.jpg')

# %% [markdown]
# ## Applying Numpy addition on images

# %%
fimg1 = img1 + img2
plt.imshow(fimg1)
plt.show()

# %% [markdown]
# ## Saving the output image

# %%
cv2.imwrite('output.jpg', fimg1)
fimg2 = img1 - img2
plt.imshow(fimg2)
plt.show()

# %% [markdown]
# ## Saving the output image

# %%
cv2.imwrite('output.jpg', fimg2)
fimg3 = img1 * img2
plt.imshow(fimg3)
plt.show()

# %% [markdown]
# ## Saving the output image

# %%
cv2.imwrite('output.jpg', fimg3)
fimg4 = img1 / img2
plt.imshow(fimg4)
plt.show()
# Out:
# C:\Users\athre\AppData\Local\Temp\ipykernel_44124\4291499296.py:2: RuntimeWarning: invalid value encountered in divide
#   fimg4 = img1 / img2
# c:\Python3.11\Lib\site-packages\matplotlib\cm.py:478: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %% [markdown]
# ## Saving the output image

# %%
cv2.imwrite('output.jpg', fimg4)
# Out:
# True
